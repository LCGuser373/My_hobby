# %% [markdown]
# # Prácticas Profesionalizantes 2024
# EEST 9
#
# # Filtramos datos y generamos mapas

# %% [markdown]
# ## Trabajo en grupo entre 2 o 3 estudiantes
# Indicar los nombres y los links de los repositorios de la actividad 3 de los integrantes:
# * Lautaro Carrasco - https://github.com/LCGuser373/My_hobby

# %% [markdown]
# # Seguimos trabajando con estos datasets

# %% [markdown]
# * [Aeropuertos Argentina](https://archivos.linti.unlp.edu.ar/index.php/s/vd9SIytO2ABbkAo).
#     * Nombre del archivo: ar-airports.csv
#     * Descargado de: https://ourairports.com/countries/AR/airports.csv
# * [Áreas protegidas](https://archivos.linti.unlp.edu.ar/index.php/s/Eqw1eAVC1pdefmb).
#     * Nombre del archivo: area_protegida.csv
#     * Descargado de: https://dnsg.ign.gob.ar/apps/api/v1/capas-sig/Geodesia+y+demarcaci%C3%B3n/L%C3%ADmites/area_protegida/csv
# * [Conectivdad Argentina](https://archivos.linti.unlp.edu.ar/index.php/s/3k2TO5sSzaAU6IY).
#     * Nombre del archivo: Conectividad_Internet.csv
#     * Descargado de :https://datos.gob.ar/dataset/enacom-conectividad-al-servicio-internet/archivo/enacom_CONEC-AL-SERVI-DE-INTER_0
# * [Datos sobre consumo cultural](https://archivos.linti.unlp.edu.ar/index.php/s/pf8NMFtr1bwxFtT).
#     * Nombre del archivo: encc_2017.csv
#     * Descargado de: https://datos.cultura.gob.ar/dataset/encuesta-nacional-de-consumos-culturales
# * [Avistajes de felinos en Argentina](https://archivos.linti.unlp.edu.ar/index.php/s/5iC9FrYWiGi11d0).
#     * Nombre del archivo: felinos_filtrado.csv
#     * Descargado de: https://www.gbif.org/
# * [Lagos argentinos](https://archivos.linti.unlp.edu.ar/index.php/s/LBNPS7EdmNSwt8z)
#     * Nombre del archivo: lagos_arg.csv
#     * Descargado de: https://www.ign.gob.ar/NuestrasActividades/Geografia/DatosArgentina/Lagos

# %% [markdown]
# # Veamos otros ejemplos para filtrar datos

# %%
import pandas as pd
Lagos = pd.read_csv('lagos_arg.csv')
Lagos.Ubicación.unique()
# Out:
# array(['Santa Cruz', 'Río Negro / Neuquén', 'Chubut', 'Buenos Aires',
#        'Río Negro', 'Neuquén',
#        'Tierra del Fuego, Antártida e Islas del Atlántico Sur'],
#       dtype=object)

# %% [markdown]
# # 1. Quiero saber cuáles son los lagos de la provincia de Chubut

# %% [markdown]
# Veamos un ejemplo donde consulto sobre los lagos de la provincia de **Santa Cruz**

# %%
Lagos[Lagos.Ubicación=='Santa Cruz']
# Out:
#                     Nombre   Ubicación  Superficie (km²)  \
# 0           Lago Argentino  Santa Cruz              1435
# 1              Lago Viedma  Santa Cruz              1166
# 4             Lago Cardiel  Santa Cruz               358
# 7             Lago Strobel  Santa Cruz               100
# 12               Lago Ghío  Santa Cruz                65
# 17            Lago Quiroga  Santa Cruz                47
# 19             Lago Nansen  Santa Cruz                42
# 20           Lago Belgrano  Santa Cruz                42
# 22            Lago Posadas  Santa Cruz                41
# 26  Lago Salitroso o Sucio  Santa Cruz                37
# 28                Lago Tar  Santa Cruz                30
# 32  Lago Asador o Guitarra  Santa Cruz                23
ubicación  Superficie (km²)  Profundidad máxima (m)  \
# 43  Lago Burmeister  Santa Cruz                14                     NaN
# 44      Lago Onelli  Santa Cruz                14                     NaN
#
#     Profundidad media (m)           Coordenadas Sup Tamaño Latitud en GMS  \
# 43                    NaN  47°57'20"S 72°12'9"O      chico     47°57'20"S
# 44                    NaN  50°6'30"S 73°20'59"O      chico      50°6'30"S
#
#    Longitud en GMS        lat        lng
# 43       72°12'9"O -47.955556 -72.202500
# 44      73°20'59"O -50.108333 -73.349722

# %% [markdown]
# Aca estamos filtrando por:
# * la provincia de **Santa Cruz** y la **superficie** sea mayor a 15
# * las columnas donde hago las consultas para filtrar son: **Ubicación** y **Superficie (km²)**

# %% [markdown]
# # 4. ¿Qué lago de Tierra del Fuego , Antártida e Islas del Atlántico Sur tiene una superficie mayor a 40?

# %%
Lagos[(Lagos.Ubicación=='Tierra del Fuego, Antártida e Islas del Atlántico Sur') & (Lagos['Superficie (km²)']>40)]
# Out:
#          Nombre                                          Ubicación  \
# 16  Lago Yehuin  Tierra del Fuego, Antártida e Islas del Atlánt...
#
#     Superficie (km²)  Profundidad máxima (m)  Profundidad media (m)  \
# 16                49                     NaN                   43.0
#
#               Coordenadas Sup Tamaño Latitud en GMS Longitud en GMS  \
# 16  54°24'43"S 67°42'55"O      medio     54°24'43"S      67°42'55"O
#
#           lat        lng
# 16 -54.411944 -67.715278

# %% [markdown]
# ## Veamos nuestros datos en un mapa

# %%
import folium

# %% [markdown]
# ¿Está instalado?

# %% [markdown]
# ## Primero: Tenemos que ubicar donde en qué **columnas** están los datos de :
# * latitud
# * longitud

# %%
Lagos.columns
# Out:
# Index(['Nombre', 'Ubicación', 'Superficie (km²)', 'Profundidad máxima (m)',
#        'Profundidad media (m)', 'Coordenadas', 'Sup Tamaño', 'Latitud en GMS',
#        'Longitud en GMS', 'lat', 'lng'],
#       dtype='object')

# %% [markdown]
# En este caso las columnas con las **coordendas** son:
# * 'Latitud en GD'
# * 'Longitud en GD'

# %% [markdown]
# ## Segundo vamos a generar un mapa **base** para luego agregar los puntos

# %%
def generar_mapa():
    attr = (
        '&copy; <a href="https://www.openstreetmap.org/copyright">OpenStreetMap</a> '
        'contributors, &copy; <a href="https://cartodb.com/attributions">CartoDB</a>'
    )

    tiles = 'https://wms.ign.gob.ar/geoserver/gwc/service/tms/1.0.0/capabaseargenmap@EPSG%3A3857@png/{z}/{x}/{-y}.png'
    m = folium.Map(
        location=(-33.457606, -65.346857),
        control_scale=True,
        zoom_start=5,
        name='es',
        tiles=tiles,
        attr=attr
    )
    return m

# %% [markdown]
# Usamos la función **generar_mapa** para tener nuestro mapa base

# %%
mapa = generar_mapa()

# %% [markdown]
# La variable **mapa** es nuestra mapa **base**

# %% [markdown]
# ### Tercero agregamos a nuestro mapa:
# En la celda de abajo pusimos el código para poder agregar los puntos, te contamos lo más importante para tener en cuenta.
# * los puntos que se encuentran en las columnas de las **coordenadas**
# ```python
# [row['lat'], row['lng']],
# ```
# * queremos que muestre el nombre del lago cuando hacemos clic sobre cada icono, por eso pusimos el nombre de la columna donde se encuentra **ese dato**
# ```python
# popup=row['Nombre']
# ```

# %%
mapa = generar_mapa()
def agregar_marca_lago(row):
    folium.Marker(
        [row['lat'], row['lng']],
        popup=row['Nombre'],
        icon=folium.Icon()
        ).add_to(mapa)
Lagos.apply(agregar_marca_lago, axis=1)
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ab7ed5d577f486907cf3e7d13b0c25cb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ab7ed5d577f486907cf3e7d13b0c25cb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ab7ed5d577f486907cf3e7d13b0c25cb = L.map(
#                 &quot;map_ab7ed5d577f486907cf3e7d13b0c25cb&quot;,
#                 {
#                     center: [-33.457606, -65.346857],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     name: &quot;es&quot;,
#                 }
#             );
#             L.control.scale().addTo(map_ab7ed5d577f486907cf3e7d13b0c25cb);
#
#
#
#
#
#             var tile_layer_406d8b4d2e34eee95c6b15c17ea5054a = L.tileLayer(
#                 &quot;https://wms.ign.gob.ar/geoserver/gwc/service/tms/1.0.0/capabaseargenmap@EPSG%3A3857@png/{z}/{x}/{-y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors, \u0026copy; \u003ca href=\&quot;https://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_406d8b4d2e34eee95c6b15c17ea5054a.addTo(map_ab7ed5d577f486907cf3e7d13b0c25cb);
#
#
#             var marker_f847b9f98e89e96e04471015d6f4f63a = L.marker(
#                 [-50.24805555555556, -72.64527777777778],
#                 {}
#             ).addTo(map_ab7ed5d577f486907cf3e7d13b0c25cb);
#
#
#             var icon_30278cd18514651fa544110307aff805 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f847b9f98e89e96e04471015d6f4f63a.setIcon(icon_30278cd18514651fa544110307aff805);
#
#
#         var popup_33f67c4c5605d0fb1a245d57dbfc1996 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_289ad12af4ab54112b71ec99b4a737c0 = $(`&lt;div id=&quot;html_289ad12af4ab54112b71ec99b4a737c0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lago Argentino&lt;/div&gt;`)[0];
#                 popup_33f67c4c5605d0fb1a245d57dbfc1996.setContent(html_289ad12af4ab54112b71ec99b4a737c0);
#
#
#
#         marker_f847b9f98e89e96e04471015d6f4f63a.bindPopup(popup_33f67c4c5605d0fb1a245d57dbfc1996)
#         ;
#
#
#
#
#             var marker_b1ba946c131e6e59351d484e8dbba9dd = L.marker(
#                 [-49.62416666666667, -72.495],
#                 {}
#             ).addTo(map_ab7ed5d577f486907cf3e7d13b0c25cb);
#
#
#             var icon_c271db86eaf88cddb5be6814f60d7d91 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b1ba946c131e6e59351d484e8dbba9dd.setIcon(icon_c271db86eaf88cddb5be6814f60d7d91);
#
#
#         var popup_dd7751f43d4c18bd50e9c86b0d5bfe50 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_521641e5449283195784cf8a0f7e7251 = $(`&lt;div id=&quot;html_521641e5449283195784cf8a0f7e7251&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lago Viedma&lt;/div&gt;`)[0];
#                 popup_dd7751f43d4c18bd50e9c86b0d5bfe50.setContent(html_521641e5449283195784cf8a0f7e7251);
#
#
#
#         marker_b1ba946c131e6e59351d484e8dbba9dd.bindPopup(popup_dd7751f43d4c18bd50e9c86b0d5bfe50)
#         ;
#
#
#
#
#             var marker_2baab53916af91dc5964af649a3e2602 = L.marker(
#                 [-40.85444444444445, -71.61611111111111],
#                 {}
#             ).addTo(map_ab7ed5d577f486907cf3e7d13b0c25cb);
#
#
#             var icon_ed6a78e4483187ba51e6aa165b69e9d7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2baab53916af91dc5964af649a3e2602.setIcon(icon_ed6a78e4483187ba51e6aa165b69e9d7);
#
#
#         var popup_22066925d3b7c16514f23f180d07953a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d06bd0bb746b641e15de16639bd8f2dd = $(`&lt;div id=&quot;html_d06bd0bb746b641e15de16639bd8f2dd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lago Nahuel Huapi&lt;/div&gt;`)[0];
#                 popup_22066925d3b7c16514f23f180d07953a.setContent(html_d06bd0bb746b641e15de16639bd8f2dd);
#
#
#
#         marker_2baab53916af91dc5964af649a3e2602.bindPopup(popup_22066925d3b7c16514f23f180d07953a)
#         ;
#
#
#
#
#             var marker_0a1505173e392d2dd3fdcbde9446f4b4 = L.marker(
#                 [-45.414722222222224, -69.19777777777779],

# %% [markdown]
# # 5. Armá tu mapa
# Con el dataset elegido mostrá los datos en un mapa

# %% [markdown]
# ## Primero encontrá los nombres de las columnas donde están las coordenadas

# %%
#pone acá el código
Lagos.columns
# Out:
# Index(['Nombre', 'Ubicación', 'Superficie (km²)', 'Profundidad máxima (m)',
#        'Profundidad media (m)', 'Coordenadas', 'Sup Tamaño', 'Latitud en GMS',
#        'Longitud en GMS', 'lat', 'lng'],
#       dtype='object')

# %% [markdown]
# ## Segundo creá tu mapa **base**

# %%
# pone acá el codigo aca
def generar_mapa():
    attr = (
        '&copy; <a href="https://www.openstreetmap.org/copyright">OpenStreetMap</a> '
        'contributors, &copy; <a href="https://cartodb.com/attributions">CartoDB</a>'
    )

    tiles = 'https://wms.ign.gob.ar/geoserver/gwc/service/tms/1.0.0/capabaseargenmap@EPSG%3A3857@png/{z}/{x}/{-y}.png'
    m = folium.Map(
        location=(-33.457606, -65.346857),
        control_scale=True,
        zoom_start=5,
        name='es',
        tiles=tiles,
        attr=attr
    )
    return m

# %% [markdown]
# ## Tercero agregá los puntos a tu mapa

# %%
mapa = generar_mapa()
def agregar_marca_lago(row):
    folium.Marker(
        [row['lat'], row['lng']],
        popup=row['Nombre'],
        icon=folium.Icon()
        ).add_to(mapa)
Lagos.apply(agregar_marca_lago, axis=1)
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fdc61555926f8f7bfb53845dc6f8a4ba {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fdc61555926f8f7bfb53845dc6f8a4ba&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fdc61555926f8f7bfb53845dc6f8a4ba = L.map(
#                 &quot;map_fdc61555926f8f7bfb53845dc6f8a4ba&quot;,
#                 {
#                     center: [-33.457606, -65.346857],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     name: &quot;es&quot;,
#                 }
#             );
#             L.control.scale().addTo(map_fdc61555926f8f7bfb53845dc6f8a4ba);
#
#
#
#
#
#             var tile_layer_5ccae14ea5c6ecd1eb95ad7a23a2f41e = L.tileLayer(
#                 &quot;https://wms.ign.gob.ar/geoserver/gwc/service/tms/1.0.0/capabaseargenmap@EPSG%3A3857@png/{z}/{x}/{-y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors, \u0026copy; \u003ca href=\&quot;https://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_5ccae14ea5c6ecd1eb95ad7a23a2f41e.addTo(map_fdc61555926f8f7bfb53845dc6f8a4ba);
#
#
#             var marker_0f58e16cec39554c417110aee040cd39 = L.marker(
#                 [-50.24805555555556, -72.64527777777778],
#                 {}
#             ).addTo(map_fdc61555926f8f7bfb53845dc6f8a4ba);
#
#
#             var icon_480385e919ca50d985837bd5c2f3dc93 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_0f58e16cec39554c417110aee040cd39.setIcon(icon_480385e919ca50d985837bd5c2f3dc93);
#
#
#         var popup_e4a89744d294ba3593455f04e9515195 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c312772892b66ab5eedea3cd53a48950 = $(`&lt;div id=&quot;html_c312772892b66ab5eedea3cd53a48950&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lago Argentino&lt;/div&gt;`)[0];
#                 popup_e4a89744d294ba3593455f04e9515195.setContent(html_c312772892b66ab5eedea3cd53a48950);
#
#
#
#         marker_0f58e16cec39554c417110aee040cd39.bindPopup(popup_e4a89744d294ba3593455f04e9515195)
#         ;
#
#
#
#
#             var marker_948fce7530b1bca3b4f4dfa2ddad9fda = L.marker(
#                 [-49.62416666666667, -72.495],
#                 {}
#             ).addTo(map_fdc61555926f8f7bfb53845dc6f8a4ba);
#
#
#             var icon_f7096dbb580b670c1e50b56ac282a6dd = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_948fce7530b1bca3b4f4dfa2ddad9fda.setIcon(icon_f7096dbb580b670c1e50b56ac282a6dd);
#
#
#         var popup_6dc763c1678da9b70751c6dff43210c2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e4dcad2fecde7f7c74e4a9987d3fdfb0 = $(`&lt;div id=&quot;html_e4dcad2fecde7f7c74e4a9987d3fdfb0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lago Viedma&lt;/div&gt;`)[0];
#                 popup_6dc763c1678da9b70751c6dff43210c2.setContent(html_e4dcad2fecde7f7c74e4a9987d3fdfb0);
#
#
#
#         marker_948fce7530b1bca3b4f4dfa2ddad9fda.bindPopup(popup_6dc763c1678da9b70751c6dff43210c2)
#         ;
#
#
#
#
#             var marker_b21f13e710285e3916f3e5f113f2aeb8 = L.marker(
#                 [-40.85444444444445, -71.61611111111111],
#                 {}
#             ).addTo(map_fdc61555926f8f7bfb53845dc6f8a4ba);
#
#
#             var icon_a18312ca7c00ed4a512e2bbb8c56ef80 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b21f13e710285e3916f3e5f113f2aeb8.setIcon(icon_a18312ca7c00ed4a512e2bbb8c56ef80);
#
#
#         var popup_490b9d70a642417a9c882dde95b0d186 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0518adfe9a499072dc402ce703214244 = $(`&lt;div id=&quot;html_0518adfe9a499072dc402ce703214244&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lago Nahuel Huapi&lt;/div&gt;`)[0];
#                 popup_490b9d70a642417a9c882dde95b0d186.setContent(html_0518adfe9a499072dc402ce703214244);
#
#
#
#         marker_b21f13e710285e3916f3e5f113f2aeb8.bindPopup(popup_490b9d70a642417a9c882dde95b0d186)
#         ;
#
#
#
#
#             var marker_dbaf4b598d867d139362508a3cce170a = L.marker(
#                 [-45.414722222222224, -69.19777777777779],
